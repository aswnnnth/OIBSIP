# %% [markdown]
# # ASWANTH K
#
# ## DATA ANALYTICS INTERNSHIP
#
# ### TASK 3 – Data Cleaning
#
# ***OASIS INFOBYTE***

# %% [markdown]
# # **Data Cleaning Project**
# ## **Load Dataset**
# The dataset is loaded into pandas for inspection and cleaning.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/content/Titanic-Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # **Dataset Overview**
# Inspect the structure, columns, data types and number of records.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # **Data Quality Report**
# Check for:
#
# Missing values
#
# Duplicate rows
#
# Data type issues

# %%
# Missing values

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Duplicate rows
df.duplicated ().sum()
# Out:
# np.int64(0)

# %%
# Summary statistics
df.describe (include="all")
# Out:
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    891.000000  891.000000  891.000000                  891   891
# unique          NaN         NaN         NaN                  891     2
# top             NaN         NaN         NaN  Dooley, Mr. Patrick  male
# freq            NaN         NaN         NaN                    1   577
# mean     446.000000    0.383838    2.308642                  NaN   NaN
# std      257.353842    0.486592    0.836071                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      223.500000    0.000000    2.000000                  NaN   NaN
# 50%      446.000000    0.000000    3.000000                  NaN   NaN
# 75%      668.500000    1.000000    3.000000                  NaN   NaN
# max      891.000000    1.000000    3.000000                  NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare Cabin Embarked
# ...

# %% [markdown]
# # **Handle Missing Values**
# The dataset contains missing values in the following columns:
#
# *AGE- 177 ,FILL WITH MEDIAN
#
# *CABIN-687, DROP OR FILL UNKNOWN
#
# *EMBARKED-2- FILL WITH MODE

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df = df.drop('Cabin', axis=1)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# # **Duplicated Rows**
# The dataset contains no duplicate rows, so no records were removed.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # **Verify Data Types**
# Ensure that each column has the appropriate data type after cleaning.

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %% [markdown]
# # **Outlier Detection**
# The Interquartile Range (IQR) method is used to identify outliers in the Fare column.

# %%
Q1 = df ["Fare"]. quantile(0.25)
Q3 = df["Fare"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df["Fare"] < lower) | (df["Fare"] > upper)]
print("Number of outliers:", len(outliers))
# Out:
# Number of outliers: 116

# %% [markdown]
# # **Before vs After Summary**
# The table below summarises the data quality improvements made during the cleaning proce

# %%
summary = pd.DataFrame({
    "Metric": [
        "Rows",
        "Columns",
        "Missing Values",
        "Duplicate Rows"
    ],
    "Before": [
        891,
        12,
        866, # Age (177) + embarked(2) + Cabin (687)
        0
    ],
    "After": [
        len(df),
        df.shape[1],
        df.isnull().sum().sum(),
        df.duplicated().sum()
    ]
})
summary
# Out:
#            Metric  Before  After
# 0            Rows     891    891
# 1         Columns      12     11
# 2  Missing Values     866      0
# 3  Duplicate Rows       0      0

# %% [markdown]
# # **Save Cleaned Dataset**

# %%
df.to_csv("cleaned_tested.csv", index=False)

# %% [markdown]
# # **Conclusion**
# The dataset was successfully cleaned by handling missing values, removing the highly incomplete Cabin column, verifying duplicate records, checking data types and detecting outliers. The cleaned dataset is now consistent , complete and suitable for further exploratory data analysis or machine learning tasks. Proper data cleaning improves data quality and ensures the future analyses produce reliable and meaningful insights.
